# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
int(1.5)
# Out:
# 1

# %%
for i in range(231):
    
    a=i**3-12.0**3
    
    if(a/231==int(a/231)):
        print i
# Out:
# 12
# 45
# 111

# %%
def V1(w):
    return sqrt(2*E/em)
def V21(w):
    return sqrt(2*E/em)
def V22(w):
     return sqrt(2*(E+hbar*w)/em)
def V3(w):
     return sqrt(2*(E+hbar*w)/em)
def aw2(w):
    return 1.0*(V22(w)-V1(w))**2 + 1.0*(V3(w)-V21(w))**2 +2.0*(V22(w)-V1(w))*(V3(w)-V21(w))*cos(w*(t3-t2))
aw2(1)
# Out:
# 0.0058095201627947589

# %%
Bremss1=zeros(len(W1))
Bremss2=zeros(len(W2))
for i in range(len(W1)):
    Bremss1[i]=2*(e**2)*aw2(W1[i])/(W1[i])
    Bremss2[i]=2*(e**2)*aw2(W2[i])/(W2[i])
print len(W1),len(Bremss1)
# Out:
# 1000 1000

# %%
plot(W1,Bremss1)
xlabel("$ \omega_{\gamma} $",size=15)
ylabel("$ dP/dE_{\gamma} $",size=15)
title("$ Bremsshtralung\ semiclassical\ $",size=15)

legend()

# %%
plot(W2,Bremss2)
xlabel("$ \omega_{\gamma} $",size=15)
ylabel("$ dP/dE_{\gamma} $",size=15)
title("$ Bremsshtralung\ semiclassical\ $",size=15)

legend()
