# %%
# %pylab inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
M=0.51*10**6

A=100
A1=60

# %%
#Matrices que se llenaran
X=zeros((A,A))#maximo valor para X es 1 para tomar problema de tunelamiento E/V_{0}
E=zeros((A,A))#valor de las energias w que se tomara
B=zeros((A,A))#valor de a_{w}**2/w
a=0.01


#valores maximos en X,Y y Z
z=[]
for i in range(A1):
    if((0.25+(i)*1.0/A1)<1):
        z.append(0.25+(i)*1.0/A1)
    #if(i*1.0/A+0.001>0.5):
    #z.append(i*1.0/A+0.001)
x=[]
for i in range(A):
    #if(i*1.0/A+0.001>0.5):
    x.append((i*1.0/A+0.001)*00.1)
    
print "minimos x,z",min(x),min(z),"maximos x,z",max(x),max(z),len(x),len(z)


for i in range(len(z)):
    for j in range(len(x)):
        
        if(x[j]>=z[i]*0.1 or z[i]==0 or x[j]<=0.05 ):
            b=0
        if(x[j]<z[i]*0.3 ):
            Dt=a*sqrt(M/(2*1-2*z[i]+2*x[j]))
            #Dt=a*sqrt(M/(2*1-2*X1+2*Egamma1[i]))
            a1=( ( (  sqrt(2*(1-z[i]+x[j])/M)  -  sqrt(2*z[i]/M)      )**2 )/x[j])
            a2=(((  sqrt(2*(z[i]-x[j])/M)   -     sqrt(2*(1-z[i])/M)  )**2 )/x[j])
            a3=abs( 2*(cos(x[j]*Dt)/x[j])* (sqrt(2*(1-z[i]+x[j])/M)   -  sqrt(2*z[i]/M)) * (sqrt(2*(z[i]-x[j])/M)   - sqrt(2*(1-z[i])/M)) )            
            b=a1+a2+a3
 
            
        X[i][j]=z[i]
        E[i][j]=x[j]
        B[i][j]=b #sin(2*pi*x[i])*sin(2*pi*x[j])
# Out:
# minimos x,z 0.0001 0.25 maximos x,z 0.0991 0.983333333333 100 45

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

Y = E
Z =B
surf = ax.plot_surface(Y,X, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
        linewidth=0, antialiased=False)
#ax.set_xlim(0,0.1)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_ylabel("$ E/V_{0}$",size=20)
ax.set_xlabel("$ E_{\gamma}/ V_{0} $",size=20)
ax.set_zlabel("$ E_{\gamma}^{-1}|a_{\omega}|^{2} $",size=20)

ax.invert_yaxis()
#ax.set_zlim(0,0.01)

fig.colorbar(surf, shrink=0.5, aspect=5)
figsize(20,8)



savefig("3d_antes.png")


plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm


fig = plt.figure()
ax = fig.gca(projection='3d')

Y=E
Z=B
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)
ax.invert_yaxis()

ax.set_xlabel("$ E/V_{0}$",size=20)
ax.set_ylabel("$ E_{\gamma}/ V_{0} $",size=20)
ax.set_zlabel("$ E_{\gamma}^{-1}|a_{\omega}|^{2} $",size=20)

#ax.invert_xaxis()
#ax.invert_yaxis()
#ax.set_ylim(0,0.1)
#ax.set_zlim(-0.01, 0.15)
#ax.set_xlim(0,0.1)




plt.show()
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/mpl_toolkits/mplot3d/axes3d.py:1673: RuntimeWarning: invalid value encountered in divide
#   for n in normals])
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/colors.py:394: RuntimeWarning: invalid value encountered in greater
#   if (c.ravel() > 1).any() or (c.ravel() < 0).any():
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/colors.py:394: RuntimeWarning: invalid value encountered in less
#   if (c.ravel() > 1).any() or (c.ravel() < 0).any():

# %%
2943097
# Out:
# 2943097
