# %%
# %pylab inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
M=0.51*10**6

A=100
A1=60

# %%
#Matrices que se llenaran
X=zeros((A,A))#maximo valor para X es 1 para tomar problema de tunelamiento E/V_{0}
E=zeros((A,A))#valor de las energias w que se tomara
B=zeros((A,A))#valor de a_{w}**2/w
a=0.01


#valores maximos en X,Y y Z
z=[]
for i in range(A1):
    if((0.25+(i)*1.0/A1)<1):
        z.append(0.25+(i)*1.0/A1)
    #if(i*1.0/A+0.001>0.5):
    #z.append(i*1.0/A+0.001)
x=[]
for i in range(A):
    #if(i*1.0/A+0.001>0.5):
    x.append((i*1.0/A+0.001)*00.1)
    
print "minimos x,z",min(x),min(z),"maximos x,z",max(x),max(z),len(x),len(z)


for i in range(len(z)):
    for j in range(len(x)):
        
        if(x[j]>=z[i]*0.1 and z[i]==0):
            b=0
        if(x[j]<z[i]*0.1):
            Dt=a*sqrt(M/(2*1-2*z[i]))
            #Dt=a*sqrt(M/(2*1-2*X1+2*Egamma1[i]))
            a1=( ( (  sqrt(2*(1-z[i]+x[j])/M)  -  sqrt(2*z[i]/M)      )**2 )/x[j])
            a2=(((  sqrt(2*(z[i]-x[j])/M)   -     sqrt(2*(1-z[i])/M)  )**2 )/x[j])
            a3=abs( 2*(cos(x[j]*Dt)/x[j])* (sqrt(2*(1-z[i]+x[j])/M)   -  sqrt(2*z[i]/M)) * (sqrt(2*(z[i]-x[j])/M)   - sqrt(2*(1-z[i])/M)) )            
            b=a3#a1+a2+a3
 
            
        X[i][j]=z[i]
        E[i][j]=x[j]
        B[i][j]=b #sin(2*pi*x[i])*sin(2*pi*x[j])
        
 
print z
# Out:
# minimos x,z 0.0001 0.25 maximos x,z 0.0991 0.983333333333 100 45
# [0.25, 0.26666666666666666, 0.2833333333333333, 0.3, 0.31666666666666665, 0.3333333333333333, 0.35, 0.3666666666666667, 0.3833333333333333, 0.4, 0.41666666666666663, 0.43333333333333335, 0.45, 0.4666666666666667, 0.48333333333333334, 0.5, 0.5166666666666666, 0.5333333333333333, 0.55, 0.5666666666666667, 0.5833333333333333, 0.6, 0.6166666666666667, 0.6333333333333333, 0.65, 0.6666666666666667, 0.6833333333333333, 0.7, 0.7166666666666667, 0.7333333333333334, 0.75, 0.7666666666666667, 0.7833333333333333, 0.8, 0.8166666666666667, 0.8333333333333334, 0.85, 0.8666666666666667, 0.8833333333333333, 0.9, 0.9166666666666666, 0.9333333333333333, 0.95, 0.9666666666666667, 0.9833333333333333]

# %%
            
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(X,E, B, rstride=10, cstride=10)

ax.invert_yaxis()
#ax.invert_xaxis()
ax.set_xlabel("$ E/V_{0}$",size=20)
ax.set_ylabel("$ E_{\gamma}/ V_{0} $",size=20)
ax.set_zlabel("$ E_{\gamma}^{-1}|a_{\omega}|^{2} $",size=20)

ax.set_zlim(0,0.2)


figsize(10,10)




plt.show()    

#print shape(X),shape(E),shape(B)
#print "X es \n",X,"\n E es \n", E

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

Y = E
Z =B
surf = ax.plot_surface(Y,X, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
        linewidth=0, antialiased=False)
#ax.set_xlim(0,0.1)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_ylabel("$ E/V_{0}$",size=20)
ax.set_xlabel("$ E_{\gamma}/ V_{0} $",size=20)
ax.set_zlabel("$ E_{\gamma}^{-1}|a_{\omega}|^{2} $",size=20)

ax.invert_yaxis()
#ax.set_xlim(0,0.005)

fig.colorbar(surf, shrink=0.5, aspect=5)
figsize(20,8)

savefig("3d_despues.png")
plt.show()
